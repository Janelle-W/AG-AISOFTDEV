# %% [markdown]
# # Day 1 - Lab 2: Generating a Product Requirements Document (PRD)
#
# **Objective:** Use the structured `day1_user_stories.json` artifact from the previous lab to generate a formal, comprehensive Product Requirements Document (PRD) in markdown format.
#
# **Estimated Time:** 60 minutes
#
# **Introduction:**
# With a validated set of user stories, we can now create a higher-level planning document: the PRD. A PRD serves as the source of truth for the product team, outlining the project's purpose, features, and requirements. In this lab, you will use an LLM to synthesize the detailed user stories into this formal document.
#
# For definitions of key terms used in this lab, please refer to the [GLOSSARY.md](../../GLOSSARY.md).

# %% [markdown]
# ## Step 1: Setup
#
# This initial block sets up our environment. It adds the project's root directory to the Python path, allowing us to import our custom `utils.py` script. We then initialize the connection to our Large Language Model (LLM) and load the JSON artifact from the previous lab.
#
# **Model Selection:**
# You can change the `model_name` parameter in the `setup_llm_client()` function to any of the models listed in `utils.py`, such as `"gemini-2.5-flash"` or `"meta-llama/Llama-3.3-70B-Instruct"`.
#
# **Helper Functions Used:**
# - `setup_llm_client()`: To configure the API client.
# - `get_completion()`: To send prompts to the LLM.
# - `load_artifact()`: To read the user stories JSON file and the PRD template.
# - `save_artifact()`: To save our generated PRD and Pydantic model.

# %%
import sys
import os
import json

# Add the project's root directory to the Python path to ensure 'utils' can be imported.
try:
    # Assumes the notebook is in 'labs/Day_01_.../'
    project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
except IndexError:
    # Fallback for different execution environments
    project_root = os.path.abspath(os.path.join(os.getcwd()))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

from utils import setup_llm_client, get_completion, save_artifact, load_artifact

# Initialize the LLM client. You can change the model here.
client, model_name, api_provider = setup_llm_client(model_name="gpt-4o")

# Load the artifact from Lab 1
user_stories_data = load_artifact("day1_user_stories.json")
if not user_stories_data:
    user_stories_data = []
# Out:
# 2025-09-22 16:13:16,380 ag_aisoftdev.utils INFO LLM Client configured provider=openai model=gpt-4o latency_ms=None artifacts_path=None

# %% [markdown]
# ## Step 2: The Challenges

# %% [markdown]
# ### Challenge 1 (Foundational): Generating a Simple PRD
#
# **Task:** Use the loaded user stories to generate a simple PRD.
#
# **Instructions:**
# 1. Create a prompt that instructs the LLM to act as a Product Manager.
# 2. Provide the `user_stories_data` as context.
# 3. Ask the LLM to generate a PRD with three sections: "Introduction", "User Personas", and "Features / User Stories".
#
# **Expected Quality:** A clean markdown document that correctly summarizes the provided user stories into the requested sections.

# %%
# Challenge 1: Generate a Simple PRD using user stories
simple_prd_prompt = f"""
You are an expert Product Manager. Using the provided user stories data below, generate a Product Requirements Document (PRD) in markdown format. The PRD should have the following sections:

1. Introduction: Briefly summarize the product and its purpose.
2. User Personas: List and describe the main user personas based on the user stories.
3. Features / User Stories: Summarize the key features and user stories in a clear, organized way.

Use the following user stories data as context:
{user_stories_data}

Format the output as a clean, professional markdown document.
"""

print("--- Generating Simple PRD ---")
if user_stories_data:
    simple_prd_output = get_completion(simple_prd_prompt, client, model_name, api_provider)
    print(simple_prd_output)
else:
    print("Skipping PRD generation because user stories are missing.")
# Out:
# --- Generating Simple PRD ---
# ```markdown
# # Product Requirements Document (PRD)
#
# ## Introduction
#
# The purpose of this product is to develop a comprehensive onboarding platform that enhances the experience for new hires, Human Resources managers, and team leaders. The platform aims to streamline the onboarding process by providing tools and resources that facilitate learning, integration, and engagement for new employees. It includes features such as interactive modules, checklists, communication tools, and personalized experiences to ensure a smooth transition and successful adaptation to the company culture and work environment.
#
# ## User Personas
#
# ### Sarah - Human Resources Manager
# Sarah is responsible for overseeing the onboarding process and ensuring that it is efficient and effective. She values tools that help facilitate communication, support, and access to essential resources for new hires.
#
# ### Emily - New Hire
# Emily is a new employee who wants to integrate smoothly into the company. She seeks interactive, engaging onboarding tools that allow her to learn at her own pace and connect with her new team and the company's culture.
#
# ### John - Team Leader
# John oversees a team and wants to ensure that new hires are effectively onboarding. He is focused on tracking progress, providing role-specific training, and ensuring that new employees are adapting well to their roles and the team dynamics.
#
# ## Features / User Stories
#
# ### Comprehensive Onboarding Checklist
# - **User Story 1:** As a Human Resources Manager, I want a comprehensive onboarding checklist so that new hires can complete tasks and goals efficiently during their onboarding period.
#   - **Acceptance Criteria:**
#     - New hires should see a list of tasks and goals.
#     - Completed tasks should be reflected in the checklist.
#
# ### Interactive Orientation Modules
# - **User Story 2:** As a New Hire, I want interactive orientation modules to learn about the company culture, values, policies, and procedures at my own pace.
#   - **Acceptance Criteria:**
#     - Progress through sections upon completion.
#     - Submit and record feedback for HR review.
#
# ### Role-Specific Training Content
# - **User Story 3:** As a Team Leader, I want role-specific training content for new hires to understand job responsibilities and team dynamics quickly.
#   - **Acceptance Criteria:**
#     - Display content tailored to the hire's responsibilities.
#     - Assess understanding through quizzes.
#
# ### Mentor Matching
# - **User Story 4:** As a Human Resources Manager, I want to match new hires with mentors for guidance and support.
#   - **Acceptance Criteria:**
#     - Pair new hires with experienced employees.
#     - Enable communication between hires and mentors.
#
# ### Knowledge Base Access
# - **User Story 5:** As a New Hire, I want access to a knowledge base for company documents, FAQs, and training materials.
#   - **Acceptance Criteria:**
#     - Find relevant documents and FAQs through search.
#     - Mark documents as read after viewing.
#
# ### Progress Tracking
# - **User Story 6:** As a Team Leader, I want to track the progress of new hires to ensure task and training completion.
#   - **Acceptance Criteria:**
#     - Reflect task completion in progress tracker.
#     - Follow up on incomplete tasks.
#
# ### Feedback and Improvement
# - **User Story 7:** As a New Hire, I want to provide feedback on the onboarding process for improvements.
#   - **Acceptance Criteria:**
#     - Record feedback for HR review.
#     - Consider suggestions for future improvements.
#
# ### Integrated Communication Tools
# - **User Story 8:** As a Human Resources Manager, I want communication tools integrated into the platform for interaction between new hires, teammates, and mentors.
#   - **Acceptance Criteria:**
#     - Enable messaging with mentors and team members.
#     - Notify recipients of messages.
#
# ### Virtual Office Tour
# - **User Story 9:** As a New Hire, I want a virtual office tour to familiarize myself with the workspace.
#   - **Acceptance Criteria:**
#     - Learn about different office areas through navigation.
#     - Contact HR for additional information.
#
# ### Calendar Integration
# - **User Story 10:** As a Team Leader, I want calendar integration for efficient scheduling of onboarding sessions and meetings.
#   - **Acceptance Criteria:**
#     - Sync sessions with new hire calendars.
#     - Send reminders before meetings.
#
# ### Quizzes and Assessments
# - **User Story 11:** As a New Hire, I want quizzes and assessments to test my understanding of training materials.
#   - **Acceptance Criteria:**
#     - Receive immediate feedback on performance.
#     - View strengths and areas for improvement.
#
# ### Gamification Elements
# - **User Story 12:** As a Human Resources Manager, I want gamification elements in the onboarding process for engagement.
#   - **Acceptance Criteria:**
#     - Earn points for task completion.
#     - Display ranking on a leaderboard.
#
# ### FAQ Section
# - **User Story 13:** As a New Hire, I want a FAQ section for quick answers to common questions.
#   - **Acceptance Criteria:**
#     - Find relevant answers in the FAQ section.
#     - Flag outdated FAQs for HR review.
#
# ### HR and Benefits Portal
# - **User Story 14:** As a Human Resources Manager, I want an HR and benefits portal for easy access to essential services.
#   - **Acceptance Criteria:**
#     - Find benefits information easily.
#     - Route HR assistance requests appropriately.
#
# ### Social Integration Features
# - **User Story 15:** As a New Hire, I want social integration features to interact with peers and participate in team-building activities.
#   - **Acceptance Criteria:**
#     - Connect with peers in social groups.
#     - Add team-building events to the calendar.
#
# ### Performance Metrics Dashboard
# - **User Story 16:** As a Team Leader, I want a performance metrics dashboard to see how well new hires are adapting.
#   - **Acceptance Criteria:**
#     - View performance metrics of task completion.
#     - Provide targeted support based on metrics.
#
# ### Mobile Compatibility
# - **User Story 17:** As a New Hire, I want the onboarding tool to be mobile compatible for access on smartphones or tablets.
#   - **Acceptance Criteria:**
#     - Display correctly on mobile devices.
#     - Sync progress across devices.
#
# ### Resource Library
# - **User Story 18:** As a Human Resources Manager, I want a resource library for new hires to access industry-specific learning materials.
#   - **Acceptance Criteria:**
#     - Find relevant articles and webinars.
#     - Review flagged outdated resources.
#
# ### Cultural Immersion Programs
# - **User Story 19:** As a New Hire, I want cultural immersion programs for better understanding and integration into the company culture.
#   - **Acceptance Criteria:**
#     - Gain understanding of company values through programs.
#     - Consider feedback for future program improvements.
#
# ### Customizable User Profiles
# - **User Story 20:** As a New Hire, I want customizable user profiles to personalize my onboarding experience and track progress.
#   - **Acceptance Criteria:**
#     - Save and reflect updated profile information.
#     - Update progress upon task completion.
# ```

# %% [markdown]
# ### Challenge 2 (Intermediate): Generating a PRD from a Template
#
# **Task:** Instead of just listing sections, we will now provide the LLM with a formal template to ensure the PRD's structure is consistent and complete.
#
# **Instructions:**
# 1. First, load the contents of `templates/prd_template.md` into a variable.
# 2. Create a new prompt that instructs the LLM to act as a Senior Product Manager.
# 3. Provide both the `user_stories_data` and the `prd_template_content` as context.
# 4. Instruct the LLM to populate the template with the information from the user stories, ensuring every section of the template is filled out.
#
# > **Tip:** The template has sections like 'Success Metrics' and 'Out of Scope' that aren't in the user stories. This is your chance to guide the LLM's creativity! Instruct it to infer logical content for these sections based on the project's overall goal.
#
# **Expected Quality:** A complete PRD that strictly follows the structure of the provided template file, demonstrating the LLM's ability to perform structured content generation.

# %%
# Load the PRD template
prd_template_content = load_artifact("templates/prd_template.md")

# Challenge 2: Generate a PRD using the template and user stories
template_prd_prompt = f"""
You are a Senior Product Manager. Using the provided user stories data and the PRD template below, generate a complete Product Requirements Document (PRD) in markdown format. 

Instructions:
- Strictly follow the structure and section headings of the provided PRD template.
- For each section, use information from the user stories where relevant.
- For sections not covered by the user stories (e.g., 'Success Metrics', 'Out of Scope'), infer logical and relevant content based on the overall project goal and context.
- Ensure the final output is a clean, professional markdown document with all template sections filled out.

PRD Template:
{prd_template_content}

User Stories Data:
{user_stories_data}
"""

print("--- Generating PRD from Template ---")
if user_stories_data and prd_template_content:
    prd_from_template_output = get_completion(template_prd_prompt, client, model_name, api_provider)
    print(prd_from_template_output)
else:
    print("Skipping PRD generation because user stories or template are missing.")
    prd_from_template_output = ""
# Out:
# --- Generating PRD from Template ---
# ```markdown
# # Product Requirements Document: Onboarding Platform
#
# | Status | **Draft** |
# | :--- | :--- |
# | **Author** | Onboarding Product Team |
# | **Version** | 1.0 |
# | **Last Updated** | [Date] |
#
# ## 1. Executive Summary & Vision
# The Onboarding Platform aims to streamline and enhance the onboarding experience for new hires by providing an integrated, user-friendly environment where they can complete tasks, learn about company culture, and interact with mentors and peers. Our vision is to create an efficient onboarding process that reduces the time to productivity for new hires while increasing engagement and satisfaction.
#
# ## 2. The Problem
#
# **2.1. Problem Statement:**
# New hires currently face a fragmented and overwhelming onboarding experience, leading to decreased initial productivity and a high volume of repetitive questions to HR and managers.
#
# **2.2. User Personas & Scenarios:**
#
# - **Persona 1: Sarah, The Human Resources Manager**
#   - Scenario: Sarah needs to manage multiple onboarding processes simultaneously and wants to ensure new hires have access to all necessary information and support without overwhelming manual intervention.
#
# - **Persona 2: Emily, The New Hire**
#   - Scenario: Emily, as a new hire, desires a smooth onboarding experience where she can learn at her own pace, have access to all resources, and feel integrated into the company culture quickly.
#
# - **Persona 3: John, The Team Leader**
#   - Scenario: John wants to ensure his team’s new hires are quickly brought up to speed with their roles and responsibilities and can monitor their progress efficiently.
#
# ## 3. Goals & Success Metrics
#
# | Goal | Key Performance Indicator (KPI) | Target |
# | :--- | :--- | :--- |
# | Improve New Hire Efficiency | Reduce time-to-first-contribution | Decrease by 20% in Q1 |
# | Reduce Support Load | Decrease repetitive questions to HR | 30% reduction in support tickets |
# | Increase Engagement | Onboarding completion rate | Achieve 95% completion rate |
#
# ## 4. Functional Requirements & User Stories
#
# ### User Stories
#
# 1. **User Story 1**
#    - **As a** Human Resources Manager
#    - **I want** a comprehensive onboarding checklist
#    - **So that** new hires can complete tasks and goals efficiently during their onboarding period.
#    - **Acceptance Criteria:**
#      - Given a new hire starts onboarding, when they access the checklist, then they should see a list of tasks and goals to complete.
#      - Given a task is completed, when the new hire marks it as done, then it should be reflected in the checklist.
#
# 2. **User Story 2**
#    - **As a** New Hire
#    - **I want** interactive orientation modules
#    - **So that** I can learn about the company culture, values, policies, and procedures at my own pace.
#    - **Acceptance Criteria:**
#      - Given I start an orientation module, when I complete a section, then I should be able to proceed to the next section.
#      - Given I finish a module, when I submit feedback, then it should be recorded for HR review.
#
# 3. **User Story 3**
#    - **As a** Team Leader
#    - **I want** role-specific training content
#    - **So that** new hires can quickly understand their job responsibilities and team dynamics.
#    - **Acceptance Criteria:**
#      - Given a new hire accesses training, when they select their role, then they should see content tailored to their responsibilities.
#      - Given a training module is completed, when the new hire submits a quiz, then their understanding should be assessed.
#
# 4. **User Story 4**
#    - **As a** Human Resources Manager
#    - **I want** to match new hires with mentors
#    - **So that** they receive guidance and support during their onboarding.
#    - **Acceptance Criteria:**
#      - Given a new hire is onboarded, when they request a mentor, then they should be paired with an experienced employee.
#      - Given a mentor is assigned, when the new hire has questions, then they should be able to contact their mentor.
#
# 5. **User Story 5**
#    - **As a** New Hire
#    - **I want** access to a knowledge base
#    - **So that** I can easily find company documents, FAQs, and training materials.
#    - **Acceptance Criteria:**
#      - Given I have a question, when I search the knowledge base, then I should find relevant documents and FAQs.
#      - Given I access a document, when I finish reading, then I should be able to mark it as read.
#
# 6. **User Story 6**
#    - **As a** Team Leader
#    - **I want** to track the progress of new hires
#    - **So that** I can ensure they are completing onboarding tasks and training modules.
#    - **Acceptance Criteria:**
#      - Given a new hire starts onboarding, when they complete a task, then it should be reflected in their progress tracker.
#      - Given I review a new hire's progress, when I see incomplete tasks, then I should be able to follow up with them.
#
# 7. **User Story 7**
#    - **As a** New Hire
#    - **I want** to provide feedback on the onboarding process
#    - **So that** improvements can be made.
#    - **Acceptance Criteria:**
#      - Given I complete a module, when I submit feedback, then it should be recorded for HR review.
#      - Given I have a suggestion, when I submit it, then it should be considered for future onboarding improvements.
#
# 8. **User Story 8**
#    - **As a** Human Resources Manager
#    - **I want** communication tools integrated into the onboarding platform
#    - **So that** new hires can interact with teammates and mentors.
#    - **Acceptance Criteria:**
#      - Given a new hire needs assistance, when they use the chat feature, then they should be able to message their mentor or team members.
#      - Given a new hire sends a message, when it is received, then the recipient should be notified.
#
# 9. **User Story 9**
#    - **As a** New Hire
#    - **I want** a virtual office tour
#    - **So that** I can familiarize myself with the company's workspace.
#    - **Acceptance Criteria:**
#      - Given I start the virtual tour, when I navigate through the sections, then I should learn about different areas of the office.
#      - Given I complete the tour, when I have questions, then I should be able to contact HR for more information.
#
# 10. **User Story 10**
#     - **As a** Team Leader
#     - **I want** calendar integration
#     - **So that** onboarding sessions and meetings are scheduled efficiently.
#     - **Acceptance Criteria:**
#       - Given a new hire is onboarded, when sessions are scheduled, then they should sync with their calendar.
#       - Given a meeting is scheduled, when the time approaches, then the new hire should receive a reminder.
#
# 11. **User Story 11**
#     - **As a** New Hire
#     - **I want** quizzes and assessments
#     - **So that** I can test my understanding of training materials.
#     - **Acceptance Criteria:**
#       - Given I complete a training module, when I take a quiz, then I should receive immediate feedback on my performance.
#       - Given I pass a quiz, when I view my results, then I should see areas of strength and improvement.
#
# 12. **User Story 12**
#     - **As a** Human Resources Manager
#     - **I want** gamification elements in the onboarding process
#     - **So that** it is more engaging for new hires.
#     - **Acceptance Criteria:**
#       - Given a new hire completes a task, when they earn points, then it should be reflected in their profile.
#       - Given a leaderboard is available, when new hires view it, then they should see their ranking compared to peers.
#
# 13. **User Story 13**
#     - **As a** New Hire
#     - **I want** a FAQ section
#     - **So that** I can quickly find answers to common questions.
#     - **Acceptance Criteria:**
#       - Given I have a question, when I access the FAQ section, then I should find relevant answers.
#       - Given a FAQ is outdated, when I report it, then it should be flagged for HR review.
#
# 14. **User Story 14**
#     - **As a** Human Resources Manager
#     - **I want** an HR and benefits portal
#     - **So that** new hires can access essential services easily.
#     - **Acceptance Criteria:**
#       - Given a new hire accesses the portal, when they search for benefits information, then they should find relevant details.
#       - Given a new hire needs HR assistance, when they submit a request, then it should be routed to the appropriate department.
#
# 15. **User Story 15**
#     - **As a** New Hire
#     - **I want** social integration features
#     - **So that** I can interact with other new hires and participate in team-building activities.
#     - **Acceptance Criteria:**
#       - Given I join a social group, when I participate in discussions, then I should be able to connect with peers.
#       - Given a team-building event is scheduled, when I RSVP, then it should be added to my calendar.
#
# 16. **User Story 16**
#     - **As a** Team Leader
#     - **I want** a performance metrics dashboard
#     - **So that** I can see how well new hires are adapting.
#     - **Acceptance Criteria:**
#       - Given a new hire completes tasks, when I view the dashboard, then I should see their performance metrics.
#       - Given a new hire is struggling, when I review their metrics, then I should be able to provide targeted support.
#
# 17. **User Story 17**
#     - **As a** New Hire
#     - **I want** the onboarding tool to be mobile compatible
#     - **So that** I can access it on my smartphone or tablet.
#     - **Acceptance Criteria:**
#       - Given I use a smartphone, when I access the tool, then it should display correctly on my device.
#       - Given I switch devices, when I log in, then my progress should be synced across all devices.
#
# 18. **User Story 18**
#     - **As a** Human Resources Manager
#     - **I want** a resource library
#     - **So that** new hires can access industry-specific learning materials.
#     - **Acceptance Criteria:**
#       - Given a new hire accesses the library, when they search for resources, then they should find relevant articles and webinars.
#       - Given a resource is outdated, when it is flagged, then it should be reviewed for updates.
#
# 19. **User Story 19**
#     - **As a** New Hire
#     - **I want** cultural immersion programs
#     - **So that** I can better understand and integrate into the company culture.
#     - **Acceptance Criteria:**
#       - Given I participate in a cultural program, when I complete it, then I should have a better understanding of company values.
#       - Given I have feedback on the program, when I submit it, then it should be considered for future improvements.
#
# 20. **User Story 20**
#     - **As a** New Hire
#     - **I want** customizable user profiles
#     - **So that** I can personalize my onboarding experience and track my progress.
#     - **Acceptance Criteria:**
#       - Given I access my profile, when I update my information, then it should be saved and reflected in the system.
#       - Given I complete a task, when I view my profile, then my progress should be updated.
#
# ## 5. Out of Scope
# This section identifies the features and functionalities that will not be included in this project phase, helping to manage expectations and focus the project scope.
#
# - Integration with external HR management systems beyond the basic calendar sync.
# - AI-driven personalized content recommendations.
# - Advanced data analytics beyond basic progress tracking and performance metrics.
#
# ## 6. Timeline
# Outline the major phases of development, key milestones, and expected delivery dates.
#
# - **Q1 2024:** Research & Requirement Gathering
# - **Q2 2024:** Development of Core Features (Onboarding Checklist, Interactive Modules)
# - **Q3 2024:** Testing & Feedback Collection
# - **Q4 2024:** Full Launch & Continuous Improvement
#
# ## 7. Dependencies & Risks
#
# - **Dependencies:**
#   - Integration with existing company calendar systems.
#   - Access to current HR content and resources for initial setup.
#
# - **Risks:**
#   - Potential delays in content creation and approval from HR.
#   - Resistance to change from new hires used to traditional onboarding methods.
#   - Technical challenges related to ensuring mobile compatibility across devices.
#
# ## 8. Appendix
# Additional information, references, or data pertinent to the PRD.
#
# - Reference to the current onboarding process documentation.
# - Survey results from recent new hires on onboarding experience.
#
# ```
#
# ```markdown
# # Product Requirements Document: Onboarding Platform
#
# | Status | **Draft** |
# | :--- | :--- |
# | **Author** | Onboarding Product Team |
# | **Version** | 1.0 |
# | **Last Updated** | [Date] |
#
# ## 1. Executive Summary & Vision
# The Onboarding Platform aims to streamline and enhance the onboarding experience for new hires by providing an integrated, user-friendly environment where they can complete tasks, learn about company culture, and interact with mentors and peers. Our vision is to create an efficient onboarding process that reduces the time to productivity for new hires while increasing engagement and satisfaction.
#
# ## 2. The Problem
#
# **2.1. Problem Statement:**
# New hires currently face a fragmented and overwhelming onboarding experience, leading to decreased initial productivity and a high volume of repetitive questions to HR and managers.
#
# **2.2. User Personas & Scenarios:**
#
# - **Persona 1: Sarah, The Human Resources Manager**
#   - Scenario: Sarah needs to manage multiple onboarding processes simultaneously and wants to ensure new hires have access to all necessary information and support without overwhelming manual intervention.
#
# - **Persona 2: Emily, The New Hire**
#   - Scenario: Emily, as a new hire, desires a smooth onboarding experience where she can learn at her own pace, have access to all resources, and feel integrated into the company culture quickly.
#
# - **Persona 3: John, The Team Leader**
#   - Scenario: John wants to ensure his team’s new hires are quickly brought up to speed with their roles and responsibilities and can monitor their progress efficiently.
#
# ## 3. Goals & Success Metrics
#
# | Goal | Key Performance Indicator (KPI) | Target |
# | :--- | :--- | :--- |
# | Improve New Hire Efficiency | Reduce time-to-first-contribution | Decrease by 20% in Q1 |
# | Reduce Support Load | Decrease repetitive questions to HR | 30% reduction in support tickets |
# | Increase Engagement | Onboarding completion rate | Achieve 95% completion rate |
#
# ## 4. Functional Requirements & User Stories
#
# ### User Stories
#
# 1. **User Story 1**
#    - **As a** Human Resources Manager
#    - **I want** a comprehensive onboarding checklist
#    - **So that** new hires can complete tasks and goals efficiently during their onboarding period.
#    - **Acceptance Criteria:**
#      - Given a new hire starts onboarding, when they access the checklist, then they should see a list of tasks and goals to complete.
#      - Given a task is completed, when the new hire marks it as done, then it should be reflected in the checklist.
#
# 2. **User Story 2**
#    - **As a** New Hire
#    - **I want** interactive orientation modules
#    - **So that** I can learn about the company culture, values, policies, and procedures at my own pace.
#    - **Acceptance Criteria:**
#      - Given I start an orientation module, when I complete a section, then I should be able to proceed to the next section.
#      - Given I finish a module, when I submit feedback, then it should be recorded for HR review.
#
# 3. **User Story 3**
#    - **As a** Team Leader
#    - **I want** role-specific training content
#    - **So that** new hires can quickly understand their job responsibilities and team dynamics.
#    - **Acceptance Criteria:**
#      - Given a new hire accesses training, when they select their role, then they should see content tailored to their responsibilities.
#      - Given a training module is completed, when the new hire submits a quiz, then their understanding should be assessed.
#
# 4. **User Story 4**
#    - **As a** Human Resources Manager
#    - **I want** to match new hires with mentors
#    - **So that** they receive guidance and support during their onboarding.
#    - **Acceptance Criteria:**
#      - Given a new hire is onboarded, when they request a mentor, then they should be paired with an experienced employee.
#      - Given a mentor is assigned, when the new hire has questions, then they should be able to contact their mentor.
#
# 5. **User Story 5**
#    - **As a** New Hire
#    - **I want** access to a knowledge base
#    - **So that** I can easily find company documents, FAQs, and training materials.
#    - **Acceptance Criteria:**
#      - Given I have a question, when I search the knowledge base, then I should find relevant documents and FAQs.
#      - Given I access a document, when I finish reading, then I should be able to mark it as read.
#
# 6. **User Story 6**
#    - **As a** Team Leader
#    - **I want** to track the progress of new hires
#    - **So that** I can ensure they are completing onboarding tasks and training modules.
#    - **Acceptance Criteria:**
#      - Given a new hire starts onboarding, when they complete a task, then it should be reflected in their progress tracker.
#      - Given I review a new hire's progress, when I see incomplete tasks, then I should be able to follow up with them.
#
# 7. **User Story 7**
#    - **As a** New Hire
#    - **I want** to provide feedback on the onboarding process
#    - **So that** improvements can be made.
#    - **Acceptance Criteria:**
#      - Given I complete a module, when I submit feedback, then it should be recorded for HR review.
#      - Given I have a suggestion, when I submit it, then it should be considered for future onboarding improvements.
#
# 8. **User Story 8**
#    - **As a** Human Resources Manager
#    - **I want** communication tools integrated into the onboarding platform
#    - **So that** new hires can interact with teammates and mentors.
#    - **Acceptance Criteria:**
#      - Given a new hire needs assistance, when they use the chat feature, then they should be able to message their mentor or team members.
#      - Given a new hire sends a message, when it is received, then the recipient should be notified.
#
# 9. **User Story 9**
#    - **As a** New Hire
#    - **I want** a virtual office tour
#    - **So that** I can familiarize myself with the company's workspace.
#    - **Acceptance Criteria:**
#      - Given I start the virtual tour, when I navigate through the sections, then I should learn about different areas of the office.
#      - Given I complete the tour, when I have questions, then I should be able to contact HR for more information.
#
# 10. **User Story 10**
#     - **As a** Team Leader
#     - **I want** calendar integration
#     - **So that** onboarding sessions and meetings are scheduled efficiently.
#     - **Acceptance Criteria:**
#       - Given a new hire is onboarded, when sessions are scheduled, then they should sync with their calendar.
#       - Given a meeting is scheduled, when the time approaches, then the new hire should receive a reminder.
#
# 11. **User Story 11**
#     - **As a** New Hire
#     - **I want** quizzes and assessments
#     - **So that** I can test my understanding of training materials.
#     - **Acceptance Criteria:**
#       - Given I complete a training module, when I take a quiz, then I should receive immediate feedback on my performance.
#       - Given I pass a quiz, when I view my results, then I should see areas of strength and improvement.
#
# 12. **User Story 12**
#     - **As a** Human Resources Manager
#     - **I want** gamification elements in the onboarding process
#     - **So that** it is more engaging for new hires.
#     - **Acceptance Criteria:**
#       - Given a new hire completes a task, when they earn points, then it should be reflected in their profile.
#       - Given a leaderboard is available, when new hires view it, then they should see their ranking compared to peers.
#
# 13. **User Story 13**
#     - **As a** New Hire
#     - **I want** a FAQ section
#     - **So that** I can quickly find answers to common questions.
#     - **Acceptance Criteria:**
#       - Given I have a question, when I access the FAQ section, then I should find relevant answers.
#       - Given a FAQ is outdated, when I report it, then it should be flagged for HR review.
#
# 14. **User Story 14**
#     - **As a** Human Resources Manager
#     - **I want** an HR and benefits portal
#     - **So that** new hires can access essential services easily.
#     - **Acceptance Criteria:**
#       - Given a new hire accesses the portal, when they search for benefits information, then they should find relevant details.
#       - Given a new hire needs HR assistance, when they submit a request, then it should be routed to the appropriate department.
#
# 15. **User Story 15**
#     - **As a** New Hire
#     - **I want** social integration features
#     - **So that** I can interact with other new hires and participate in team-building activities.
#     - **Acceptance Criteria:**
#       - Given I join a social group, when I participate in discussions, then I should be able to connect with peers.
#       - Given a team-building event is scheduled, when I RSVP, then it should be added to my calendar.
#
# 16. **User Story 16**
#     - **As a** Team Leader
#     - **I want** a performance metrics dashboard
#     - **So that** I can see how well new hires are adapting.
#     - **Acceptance Criteria:**
#       - Given a new hire completes tasks, when I view the dashboard, then I should see their performance metrics.
#       - Given a new hire is struggling, when I review their metrics, then I should be able to provide targeted support.
#
# 17. **User Story 17**
#     - **As a** New Hire
#     - **I want** the onboarding tool to be mobile compatible
#     - **So that** I can access it on my smartphone or tablet.
#     - **Acceptance Criteria:**
#       - Given I use a smartphone, when I access the tool, then it should display correctly on my device.
#       - Given I switch devices, when I log in, then my progress should be synced across all devices.
#
# 18. **User Story 18**
#     - **As a** Human Resources Manager
#     - **I want** a resource library
#     - **So that** new hires can access industry-specific learning materials.
#     - **Acceptance Criteria:**
#       - Given a new hire accesses the library, when they search for resources, then they should find relevant articles and webinars.
#       - Given a resource is outdated, when it is flagged, then it should be reviewed for updates.
#
# 19. **User Story 19**
#     - **As a** New Hire
#     - **I want** cultural immersion programs
#     - **So that** I can better understand and integrate into the company culture.
#     - **Acceptance Criteria:**
#       - Given I participate in a cultural program, when I complete it, then I should have a better understanding of company values.
#       - Given I have feedback on the program, when I submit it, then it should be considered for future improvements.
#
# 20. **User Story 20**
#     - **As a** New Hire
#     - **I want** customizable user profiles
#     - **So that** I can personalize my onboarding experience and track my progress.
#     - **Acceptance Criteria:**
#       - Given I access my profile, when I update my information, then it should be saved and reflected in the system.
#       - Given I complete a task, when I view my profile, then my progress should be updated.
#
# ## 5. Out of Scope
# This section identifies the features and functionalities that will not be included in this project phase, helping to manage expectations and focus the project scope.
#
# - Integration with external HR management systems beyond the basic calendar sync.
# - AI-driven personalized content recommendations.
# - Advanced data analytics beyond basic progress tracking and performance metrics.
#
# ## 6. Timeline
# Outline the major phases of development, key milestones, and expected delivery dates.
#
# - **Q1 2024:** Research & Requirement Gathering
# - **Q2 2024:** Development of Core Features (Onboarding Checklist, Interactive Modules)
# - **Q3 2024:** Testing & Feedback Collection
# - **Q4 2024:** Full Launch & Continuous Improvement
#
# ## 7. Dependencies & Risks
#
# - **Dependencies:**
#   - Integration with existing company calendar systems.
#   - Access to current HR content and resources for initial setup.
#
# - **Risks:**
#   - Potential delays in content creation and approval from HR.
#   - Resistance to change from new hires used to traditional onboarding methods.
#   - Technical challenges related to ensuring mobile compatibility across devices.
#
# ## 8. Appendix
# Additional information, references, or data pertinent to the PRD.
#
# - Reference to the current onboarding process documentation.
# - Survey results from recent new hires on onboarding experience.
#
# ```

# %% [markdown]
# ### Challenge 3 (Advanced): Programmatic Validation with Pydantic
#
# **Task:** We will now create a Pydantic model to represent the structure of our PRD. This allows us to programmatically validate any PRD, ensuring it meets our standards before it's accepted as a formal artifact.
#
# **Instructions:**
# 1.  Prompt the LLM to generate a Pydantic model that reflects the structure of the `prd_template.md`. The model should have fields for each major section (e.g., `introduction: str`, `user_personas: List[str]`, `user_stories: List[Dict]`).
# 2.  Save this generated model code to a file named `app/validation_models/prd_model.py`.
# 3.  While we won't write the full validation script in this lab, generating the Pydantic model itself is the key advanced step. It creates a reusable, code-based standard for our documentation.
#
# **Expected Quality:** A Python file containing a valid Pydantic model that can be used in the future to validate PRD documents automatically. This represents a shift from manual document review to automated governance.

# %%
# Challenge 3: Generate a Pydantic model for the PRD structure
pydantic_model_prompt = f"""
You are a Python expert. Based on the PRD template below, generate a Pydantic model named 'ProductRequirementsDocument' that represents the structure of the PRD. Use appropriate types from Python's 'typing' library for each field. Each major section of the template should be reflected as a field in the model. For example, use 'introduction: str', 'user_personas: List[str]', 'user_stories: List[Dict]'.

PRD Template:
{prd_template_content}
"""

print("--- Generating Pydantic Model for PRD ---")
if prd_template_content:
    pydantic_model_code = get_completion(pydantic_model_prompt, client, model_name, api_provider)
    # Clean up the code if it's wrapped in markdown fences
    if '```' in pydantic_model_code:
        pydantic_model_code = pydantic_model_code.split('```')[1].lstrip('python').strip()
    print("\n--- Generated Pydantic Model ---")
    print(pydantic_model_code)
    # Save the generated Pydantic model code to a file.
    model_path = "app/validation_models/prd_model.py"
    save_artifact(pydantic_model_code, model_path)
else:
    print("Skipping Pydantic model generation because template is missing.")

# Finally, save the completed PRD from the intermediate challenge
if prd_from_template_output:
    save_artifact(prd_from_template_output, "day1_prd.md")
# Out:
# --- Generating Pydantic Model for PRD ---
#
# --- Generated Pydantic Model ---
# from pydantic import BaseModel
# from typing import List, Dict, Optional
# from datetime import date
#
# class UserPersona(BaseModel):
#     name: str
#     scenario: str
#
# class Goal(BaseModel):
#     goal: str
#     kpi: str
#     target: str
#
# class UserStory(BaseModel):
#     # Assuming user stories are defined as dicts with key-value pairs
#     # You can replace this with a more detailed structure if available
#     title: str
#     description: str
#
# class ProductRequirementsDocument(BaseModel):
#     status: str
#     author: str
#     version: float
#     last_updated: date
#     executive_summary_vision: str
#     problem_statement: str
#     user_personas: List[UserPersona]
#     goals: List[Goal]
#     user_stories: List[UserStory]
#
# # Example instantiation:
# prd_example = ProductRequirementsDocument(
#     status="Draft",
#     author="Your Name / Team Name",
#     version=1.0,
#     last_updated=date.today(),
#     executive_summary_vision="Provide a summary of the product's purpose...",
#     problem_statement="Clearly and concisely describe the primary problem...",
#     user_personas=[
#         UserPersona(name="The New Hire", scenario="A typical scenario they face..."),
#         UserPersona(name="The Hiring Manager", scenario="A typical scenario they face..."),
#         UserPersona(name="The HR Coordinator", scenario="A typical scenario they face...")
#     ],
#     goals=[
#         Goal(goal="Improve New Hire Efficiency", kpi="Reduce time-to-first-contribution", target="Decrease by 20% in Q1"),
#         Goal(goal="Reduce Support Load", kpi="Decrease repetitive questions to HR", target="30% reduction in support tickets"),
#         Goal(goal="Increase Engagement", kpi="Onboarding completion rate", target="Achieve 95% completion rate")
#     ],
#     user_stories=[
#         UserStory(title="Sample User Story 1", description="Description of user story 1"),
#         UserStory(title="Sample User Story 2", description="Description of user story 2")
#     ]
# )
#
# --- Generated Pydantic Model ---
# from pydantic import BaseModel
# from typing import List, Dict, Optional
# from datetime import date
#
# class UserPersona(BaseModel):
#     name: str
#     scenario: str
#
# class Goal(BaseModel):
#     goal: str
#     kpi: str
#     target: str
#
# class UserStory(BaseModel):
#     # Assuming user stories are defined as dicts with key-value pairs
#     # You can replace this with a more detailed structure if available
#     title: str
#     description: str
#
# class ProductRequirementsDocument(BaseModel):
#     status: str
#     author: str
#     version: float
#     last_updated: date
#     executive_summary_vision: str
#     problem_statement: str
#     user_personas: List[UserPersona]
#     goals: List[Goal]
#     user_stories: List[UserStory]
#
# # Example instantiation:
# prd_example = ProductRequirementsDocument(
#     status="Draft",
#     author="Your Name / Team Name",
#     version=1.0,
#     last_updated=date.today(),
#     executive_summary_vision="Provide a summary of the product's purpose...",
#     problem_statement="Clearly and concisely describe the primary problem...",
#     user_personas=[
#         UserPersona(name="The New Hire", scenario="A typical scenario they face..."),
#         UserPersona(name="The Hiring Manager", scenario="A typical scenario they face..."),
#         UserPersona(name="The HR Coordinator", scenario="A typical scenario they face...")
#     ],
#     goals=[
#         Goal(goal="Improve New Hire Efficiency", kpi="Reduce time-to-first-contribution", target="Decrease by 20% in Q1"),
#         Goal(goal="Reduce Support Load", kpi="Decrease repetitive questions to HR", target="30% reduction in support tickets"),
#         Goal(goal="Increase Engagement", kpi="Onboarding completion rate", target="Achieve 95% completion rate")
#     ],
#     user_stories=[
#         UserStory(title="Sample User Story 1", description="Description of user story 1"),
#         UserStory(title="Sample User Story 2", description="Description of user story 2")
#     ]
# )

# %% [markdown]
# ## Lab Conclusion
#
# Excellent work! You have now taken the structured user stories from the first lab and synthesized them into a formal Product Requirements Document. You also created a Pydantic model to enforce the structure of this document, introducing automated governance into your workflow. The `day1_prd.md` artifact will be the primary input for Day 2, where we will begin designing our system's architecture and database.
#
# > **Key Takeaway:** Using an LLM to populate a pre-defined template is a powerful pattern for creating consistent, high-quality documentation at scale. It combines the LLM's language skills with your required structure.
