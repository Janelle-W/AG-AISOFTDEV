# %% [markdown]
# # Day 3 - Lab 2: Refactoring & Documentation
#
# **Objective:** Use an LLM to refactor a complex Python function to improve its readability and maintainability, and then generate comprehensive, high-quality documentation for the project.
#
# **Estimated Time:** 60 minutes
#
# **Introduction:**
# Writing code is only the first step; writing *good* code is what makes a project successful in the long run. In this lab, you will use an LLM as a code quality expert. You will refactor a poorly written function to make it cleaner and then generate professional-grade documentation, including docstrings and a README file. These are high-value tasks that AI can significantly accelerate.
#
# For definitions of key terms used in this lab, please refer to the [GLOSSARY.md](../../GLOSSARY.md).

# %% [markdown]
# ## Step 1: Setup
#
# We will set up our environment and define a sample of poorly written code that we will use as the target for our refactoring and documentation efforts.
#
# **Model Selection:**
# Models with strong coding and reasoning abilities are best for this task. `gpt-4.1`, `o3`, or `codex-mini` are great choices. You can also try more general models like `gemini-2.5-pro`.
#
# **Helper Functions Used:**
# - `setup_llm_client()`: To configure the API client.
# - `get_completion()`: To send prompts to the LLM.
# - `save_artifact()`: To save the generated README file.
# - `clean_llm_output()`: To clean up the generated code and documentation.

# %%
import sys
import os

# Add the project's root directory to the Python path to ensure 'utils' can be imported.
try:
    project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
except IndexError:
    project_root = os.path.abspath(os.path.join(os.getcwd()))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

from utils import setup_llm_client, get_completion, save_artifact, clean_llm_output

client, model_name, api_provider = setup_llm_client(model_name="gpt-4.1")
# Out:
# 2025-09-24 14:28:35,595 ag_aisoftdev.utils INFO LLM Client configured provider=openai model=gpt-4.1 latency_ms=None artifacts_path=None

# %% [markdown]
# ## Step 2: The Code to Improve
#
# Here is a sample Python function that is functional but poorly written. It's hard to read, has no comments or type hints, and mixes multiple responsibilities. This is the code we will improve.

# %%
bad_code = """
def process_data(data, operation):
    if operation == 'sum':
        total = 0
        for i in data:
            total += i
        return total
    elif operation == 'average':
        total = 0
        for i in data:
            total += i
        return total / len(data)
    elif operation == 'max':
        max_val = data[0]
        for i in data:
            if i > max_val:
                max_val = i
        return max_val
"""

# %% [markdown]
# ## Step 3: The Challenges

# %% [markdown]
# ### Challenge 1 (Foundational): Refactoring the Code
#
# **Task:** Use the LLM to refactor the `bad_code` to be more readable, efficient, and maintainable.
#
# **Instructions:**
# 1.  Create a prompt that instructs the LLM to act as a senior Python developer.
# 2.  Provide the `bad_code` as context.
# 3.  Ask the LLM to refactor the code. Be specific about the improvements you want, such as:
#     * Breaking the single function into multiple, smaller functions.
#     * Using built-in Python functions where appropriate (e.g., `sum()`, `max()`).
#     * Adding clear type hints and return types.
#
# > **Tip:** When you ask the AI to refactor, give it a principle to follow. For example, ask it to apply the 'Single Responsibility Principle,' which means each function should do only one thing. This guides the AI to create cleaner, more modular code.
#
# **Expected Quality:** A block of Python code that is functionally identical to the original but is significantly cleaner, more modular, and easier to understand.

# %%
# TODO: Write a prompt to refactor the 'bad_code'.
refactor_prompt = f"""
You are a senior Python developer. Refactor the following function to improve readability, maintainability, and efficiency. Apply the Single Responsibility Principle: break the function into smaller functions, each handling one operation. Use built-in Python functions (such as sum() and max()) where appropriate. Add clear type hints and return types. Do not change the functionality.

Code to refactor:
{bad_code}
"""

print("--- Refactoring Code ---")
refactored_code = get_completion(refactor_prompt, client, model_name, api_provider)
cleaned_code = clean_llm_output(refactored_code, language='python')
print(cleaned_code)
# Out:
# --- Refactoring Code ---
# from typing import List, Any
#
# def calculate_sum(data: List[float]) -> float:
#     return sum(data)
#
# def calculate_average(data: List[float]) -> float:
#     return sum(data) / len(data) if data else 0.0
#
# def calculate_max(data: List[float]) -> float:
#     return max(data)
#
# def process_data(data: List[float], operation: str) -> float:
#     if operation == 'sum':
#         return calculate_sum(data)
#     elif operation == 'average':
#         return calculate_average(data)
#     elif operation == 'max':
#         return calculate_max(data)
#     else:
#         raise ValueError(f"Unsupported operation: {operation}")
# from typing import List, Any
#
# def calculate_sum(data: List[float]) -> float:
#     return sum(data)
#
# def calculate_average(data: List[float]) -> float:
#     return sum(data) / len(data) if data else 0.0
#
# def calculate_max(data: List[float]) -> float:
#     return max(data)
#
# def process_data(data: List[float], operation: str) -> float:
#     if operation == 'sum':
#         return calculate_sum(data)
#     elif operation == 'average':
#         return calculate_average(data)
#     elif operation == 'max':
#         return calculate_max(data)
#     else:
#         raise ValueError(f"Unsupported operation: {operation}")

# %% [markdown]
# ### Challenge 2 (Intermediate): Generating Docstrings
#
# **Task:** Prompt the LLM to generate high-quality docstrings for the newly refactored code.
#
# **Instructions:**
# 1.  Create a new prompt.
# 2.  Provide the `refactored_code` from the previous step as context.
# 3.  Instruct the LLM to generate Google-style Python docstrings for each function.
# 4.  The docstrings should include a description of the function, its arguments (`Args:`), and what it returns (`Returns:`).
#
# **Expected Quality:** The refactored Python code, now with complete and professional-looking docstrings for each function.

# %%
# TODO: Write a prompt to add Google-style docstrings to the refactored code.
docstring_prompt = f"""
You are a senior Python developer. Add Google-style Python docstrings to each function in the following code. Each docstring should include:
- A brief description of the function's purpose.
- Arguments section (`Args:`) describing each parameter and its type.
- Returns section (`Returns:`) describing the return value and its type.

Code to document:
{refactored_code}
"""

print("--- Generating Docstrings ---")
code_with_docstrings = get_completion(docstring_prompt, client, model_name, api_provider)
cleaned_code_with_docstrings = clean_llm_output(code_with_docstrings, language='python')
print(cleaned_code_with_docstrings)
# Out:
# --- Generating Docstrings ---
# from typing import List, Any
#
# def calculate_sum(data: List[float]) -> float:
#     """Calculates the sum of a list of floats.
#
#     Args:
#         data (List[float]): A list of float numbers to sum.
#
#     Returns:
#         float: The sum of all elements in the list.
#     """
#     return sum(data)
#
# def calculate_average(data: List[float]) -> float:
#     """Calculates the average of a list of floats.
#
#     Args:
#         data (List[float]): A list of float numbers to average.
#
#     Returns:
#         float: The average of the list. Returns 0.0 if the list is empty.
#     """
#     return sum(data) / len(data) if data else 0.0
#
# def calculate_max(data: List[float]) -> float:
#     """Finds the maximum value in a list of floats.
#
#     Args:
#         data (List[float]): A list of float numbers.
#
#     Returns:
#         float: The maximum value in the list.
#     """
#     return max(data)
#
# def process_data(data: List[float], operation: str) -> float:
#     """Processes a list of floats with the specified operation.
#
#     Args:
#         data (List[float]): A list of float numbers to process.
#         operation (str): The operation to perform. Supported values are 'sum', 'average', and 'max'.
#
#     Returns:
#         float: The result of the specified operation.
#
#     Raises:
#         ValueError: If the operation is not supported.
#     """
#     if operation == 'sum':
#         return calculate_sum(data)
#     elif operation == 'average':
#         return calculate_average(data)
#     elif operation == 'max':
#         return calculate_max(data)
#     else:
#         raise ValueError(f"Unsupported operation: {operation}")
# from typing import List, Any
#
# def calculate_sum(data: List[float]) -> float:
#     """Calculates the sum of a list of floats.
#
#     Args:
#         data (List[float]): A list of float numbers to sum.
#
#     Returns:
#         float: The sum of all elements in the list.
#     """
#     return sum(data)
#
# def calculate_average(data: List[float]) -> float:
#     """Calculates the average of a list of floats.
#
#     Args:
#         data (List[float]): A list of float numbers to average.
#
#     Returns:
#         float: The average of the list. Returns 0.0 if the list is empty.
#     """
#     return sum(data) / len(data) if data else 0.0
#
# def calculate_max(data: List[float]) -> float:
#     """Finds the maximum value in a list of floats.
#
#     Args:
#         data (List[float]): A list of float numbers.
#
#     Returns:
#         float: The maximum value in the list.
#     """
#     return max(data)
#
# def process_data(data: List[float], operation: str) -> float:
#     """Processes a list of floats with the specified operation.
#
#     Args:
#         data (List[float]): A list of float numbers to process.
#         operation (str): The operation to perform. Supported values are 'sum', 'average', and 'max'.
#
#     Returns:
#         float: The result of the specified operation.
#
#     Raises:
#         ValueError: If the operation is not supported.
#     """
#     if operation == 'sum':
#         return calculate_sum(data)
#     elif operation == 'average':
#         return calculate_average(data)
#     elif operation == 'max':
#         return calculate_max(data)
#     else:
#         raise ValueError(f"Unsupported operation: {operation}")

# %% [markdown]
# ### Challenge 3 (Advanced): Generating a Project README
#
# **Task:** Generate a comprehensive `README.md` file for the entire Onboarding Tool project.
#
# **Instructions:**
# 1.  Create a final prompt that instructs the LLM to act as a technical writer.
# 2.  This time, you will provide multiple pieces of context: the `day1_prd.md` and the `app/main.py` source code. (You will need to load these files).
# 3.  Ask the LLM to generate a `README.md` file with the following sections:
#     * Project Title
#     * Overview (based on the PRD)
#     * Features
#     * API Endpoints (with `curl` examples)
#     * Setup and Installation instructions.
# 4.  Save the final output to `README.md` in the project's root directory.
#
# **Expected Quality:** A complete, professional `README.md` file that provides a comprehensive overview of the project for other developers.

# %%
from utils import setup_llm_client, get_completion, save_artifact, clean_llm_output, load_artifact
import json
# Load the necessary context files
prd_content = load_artifact("artifacts/day1_prd.md")
api_code = load_artifact("app/main.py")

# TODO: Write a prompt to generate a complete README.md file.
readme_prompt = f"""
You are a technical writer. Using the following PRD and API source code
PRD:
{json.dumps(prd_content)}

API Source Code:
{json.dumps(api_code)}, generate a relevant comprehensive professional README.md for the Onboarding Tool project. The README should include:
- Project Title
- Overview (based on the PRD)
- Features
- API Endpoints (with curl examples)
- Setup and Installation instructions

(no markdown fences)

"""

print("--- Generating Project README ---")
if prd_content and api_code:
    readme_content = get_completion(readme_prompt, client, model_name, api_provider)
    cleaned_readme = clean_llm_output(readme_content, language='markdown')
    print(cleaned_readme)
    save_artifact(cleaned_readme, "README.md", overwrite=True)
else:
    print("Skipping README generation because PRD or API code is missing.")
# Out:
# --- Generating Project README ---
# # Onboarding Tool
#
# ## Overview
#
# The **Onboarding Tool** is a modern platform designed to streamline and enhance the onboarding experience for new hires. It provides an integrated, user-friendly environment where HR managers, new employees, and team leaders can manage and monitor onboarding tasks, access resources, engage with mentors, and track progress. The vision is to accelerate new hire productivity, boost engagement, and reduce repetitive support overhead for HR and managers.
#
# Key objectives include:
# - Reducing the time to productivity for new hires.
# - Increasing onboarding engagement and completion rates.
# - Decreasing repetitive HR support requests.
# - Providing a comprehensive, centralized onboarding solution.
#
# ## Features
#
# - **User Management**: Create, update, delete, and retrieve users in the onboarding system.
# - **Role & Team Assignment**: Assign roles, managers, and teams to users.
# - **Gamification**: Track onboarding points for engagement.
# - **Profile Customization**: Support for profile pictures and customizable fields.
# - **Progress Tracking**: Store and access onboarding start dates and progress.
# - **Secure & Unique Accounts**: Email-based unique user identification.
# - **API-first Design**: RESTful endpoints for easy integration with other onboarding modules.
#
# ## API Endpoints
#
# Base URL: `http://localhost:8000`
#
# ### Create a New User
#
# **POST /users/**
#
# Example Request:
# curl -X POST "http://localhost:8000/users/" \
#   -H "Content-Type: application/json" \
#   -d '{
#     "first_name": "Alice",
#     "last_name": "Smith",
#     "email": "alice.smith@example.com",
#     "password_hash": "hashedpassword",
#     "role_id": 2,
#     "manager_id": 1,
#     "team_id": 1,
#     "start_date": "2024-07-01T09:00:00",
#     "gamification_points": 0,
#     "profile_picture_url": "https://example.com/pic.jpg"
#   }'
#
# ### List Users
#
# **GET /users/**
#
# Example Request:
# curl -X GET "http://localhost:8000/users/"
#
# Supports pagination:
# curl -X GET "http://localhost:8000/users/?skip=0&limit=50"
#
# ### Retrieve a User by ID
#
# **GET /users/{user_id}**
#
# Example Request:
# curl -X GET "http://localhost:8000/users/1"
#
# ### Update a User
#
# **PUT /users/{user_id}**
#
# Example Request:
# curl -X PUT "http://localhost:8000/users/1" \
#   -H "Content-Type: application/json" \
#   -d '{
#     "first_name": "Alicia",
#     "gamification_points": 10
#   }'
#
# ### Delete a User
#
# **DELETE /users/{user_id}**
#
# Example Request:
# curl -X DELETE "http://localhost:8000/users/1"
#
# ## Setup and Installation
#
# ### Prerequisites
#
# - Python 3.8+
# - [pip](https://pip.pypa.io/en/stable/)
# - [SQLite](https://www.sqlite.org/) (default, included with Python)
#
# ### 1. Clone the Repository
#
# git clone https://github.com/your-org/onboarding-tool.git
# cd onboarding-tool
#
# ### 2. Set Up a Virtual Environment (Recommended)
#
# python -m venv venv
# source venv/bin/activate   # On Windows: venv\Scripts\activate
#
# ### 3. Install Dependencies
#
# pip install -r requirements.txt
#
# Typical requirements include:
# - fastapi
# - uvicorn
# - sqlalchemy
# - pydantic
#
# You may generate a `requirements.txt` with:
# pip freeze > requirements.txt
#
# ### 4. Run the Application
#
# uvicorn main:app --reload
#
# By default, the app will start at: [http://localhost:8000](http://localhost:8000)
#
# ### 5. API Documentation
#
# Interactive Swagger UI is available at:
# http://localhost:8000/docs
#
# Redoc documentation is available at:
# http://localhost:8000/redoc
#
# ### 6. Database
#
# - Uses a local SQLite database at `artifacts/onboarding.db`.
# - The database tables will be created automatically on first run.
#
# ---
#
# For more information on onboarding features, user stories, and roadmap, refer to the Product Requirements Document (PRD) or contact the Onboarding Product Team.
# # Onboarding Tool
#
# ## Overview
#
# The **Onboarding Tool** is a modern platform designed to streamline and enhance the onboarding experience for new hires. It provides an integrated, user-friendly environment where HR managers, new employees, and team leaders can manage and monitor onboarding tasks, access resources, engage with mentors, and track progress. The vision is to accelerate new hire productivity, boost engagement, and reduce repetitive support overhead for HR and managers.
#
# Key objectives include:
# - Reducing the time to productivity for new hires.
# - Increasing onboarding engagement and completion rates.
# - Decreasing repetitive HR support requests.
# - Providing a comprehensive, centralized onboarding solution.
#
# ## Features
#
# - **User Management**: Create, update, delete, and retrieve users in the onboarding system.
# - **Role & Team Assignment**: Assign roles, managers, and teams to users.
# - **Gamification**: Track onboarding points for engagement.
# - **Profile Customization**: Support for profile pictures and customizable fields.
# - **Progress Tracking**: Store and access onboarding start dates and progress.
# - **Secure & Unique Accounts**: Email-based unique user identification.
# - **API-first Design**: RESTful endpoints for easy integration with other onboarding modules.
#
# ## API Endpoints
#
# Base URL: `http://localhost:8000`
#
# ### Create a New User
#
# **POST /users/**
#
# Example Request:
# curl -X POST "http://localhost:8000/users/" \
#   -H "Content-Type: application/json" \
#   -d '{
#     "first_name": "Alice",
#     "last_name": "Smith",
#     "email": "alice.smith@example.com",
#     "password_hash": "hashedpassword",
#     "role_id": 2,
#     "manager_id": 1,
#     "team_id": 1,
#     "start_date": "2024-07-01T09:00:00",
#     "gamification_points": 0,
#     "profile_picture_url": "https://example.com/pic.jpg"
#   }'
#
# ### List Users
#
# **GET /users/**
#
# Example Request:
# curl -X GET "http://localhost:8000/users/"
#
# Supports pagination:
# curl -X GET "http://localhost:8000/users/?skip=0&limit=50"
#
# ### Retrieve a User by ID
#
# **GET /users/{user_id}**
#
# Example Request:
# curl -X GET "http://localhost:8000/users/1"
#
# ### Update a User
#
# **PUT /users/{user_id}**
#
# Example Request:
# curl -X PUT "http://localhost:8000/users/1" \
#   -H "Content-Type: application/json" \
#   -d '{
#     "first_name": "Alicia",
#     "gamification_points": 10
#   }'
#
# ### Delete a User
#
# **DELETE /users/{user_id}**
#
# Example Request:
# curl -X DELETE "http://localhost:8000/users/1"
#
# ## Setup and Installation
#
# ### Prerequisites
#
# - Python 3.8+
# - [pip](https://pip.pypa.io/en/stable/)
# - [SQLite](https://www.sqlite.org/) (default, included with Python)
#
# ### 1. Clone the Repository
#
# git clone https://github.com/your-org/onboarding-tool.git
# cd onboarding-tool
#
# ### 2. Set Up a Virtual Environment (Recommended)
#
# python -m venv venv
# source venv/bin/activate   # On Windows: venv\Scripts\activate
#
# ### 3. Install Dependencies
#
# pip install -r requirements.txt
#
# Typical requirements include:
# - fastapi
# - uvicorn
# - sqlalchemy
# - pydantic
#
# You may generate a `requirements.txt` with:
# pip freeze > requirements.txt
#
# ### 4. Run the Application
#
# uvicorn main:app --reload
#
# By default, the app will start at: [http://localhost:8000](http://localhost:8000)
#
# ### 5. API Documentation
#
# Interactive Swagger UI is available at:
# http://localhost:8000/docs
#
# Redoc documentation is available at:
# http://localhost:8000/redoc
#
# ### 6. Database
#
# - Uses a local SQLite database at `artifacts/onboarding.db`.
# - The database tables will be created automatically on first run.
#
# ---
#
# For more information on onboarding features, user stories, and roadmap, refer to the Product Requirements Document (PRD) or contact the Onboarding Product Team.

# %% [markdown]
# ## Lab Conclusion
#
# Well done! You have used an LLM to perform two of the most valuable code quality tasks: refactoring and documentation. You've seen how AI can help transform messy code into a clean, maintainable structure and how it can generate comprehensive documentation from high-level project artifacts and source code. These skills are a massive productivity multiplier for any development team.
#
# > **Key Takeaway:** LLMs excel at understanding and generating structured text, whether that structure is code or documentation. Providing a clear 'before' state (the bad code) and a clear goal (the refactoring principles) allows the AI to perform complex code transformation and documentation tasks efficiently.
